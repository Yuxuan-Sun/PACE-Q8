# %%
v = []

first = []
for d in range(5,21):
    current = []
    for k in range(0, d):
        p1 = binomial(d+1, k+1) + binomial(d,k+1) - binomial(d-2,k+1) + binomial(d,k)
        current.append(p1)
    first.append(current)
    print(d, current)
# Out:
# 5 [9, 27, 39, 30, 12]
# 6 [10, 36, 66, 69, 42, 14]
# 7 [11, 46, 102, 135, 111, 56, 16]
# 8 [12, 57, 148, 237, 246, 167, 72, 18]
# 9 [13, 69, 205, 385, 483, 413, 239, 90, 20]
# 10 [14, 82, 274, 590, 868, 896, 652, 329, 110, 22]
# 11 [15, 96, 356, 864, 1458, 1764, 1548, 981, 439, 132, 24]
# 12 [16, 111, 452, 1220, 2322, 3222, 3312, 2529, 1420, 571, 156, 26]
# 13 [17, 127, 563, 1672, 3542, 5544, 6534, 5841, 3949, 1991, 727, 182, 28]
# 14 [18, 144, 690, 2235, 5214, 9086, 12078, 12375, 9790, 5940, 2718, 909, 210, 30]
# 15 [19, 162, 834, 2925, 7449, 14300, 21164, 24453, 22165, 15730, 8658, 3627, 1119, 240, 32]
# 16 [20, 181, 996, 3759, 10374, 21749, 35464, 45617, 46618, 37895, 24388, 12285, 4746, 1359, 272, 34]
# 17 [21, 201, 1177, 4755, 14133, 32123, 57213, 81081, 92235, 84513, 62283, 36673, 17031, 6105, 1631, 306, 36]
# 18 [22, 222, 1378, 5932, 18888, 46256, 89336, 138294, 173316, 176748, 146796, 98956, 53704, 23136, 7736, 1937, 342, 38]
# ...

# %%
v = []

second = []
for d in range(5,21):
    current = []
    for k in range(0, d):
        p1 = binomial(d+2, k+1) + binomial(d+1,k+1) - binomial(d,k+1)
        current.append(p1)
    second.append(current)
    print(d, current)
# Out:
# 5 [8, 26, 45, 45, 26]
# 6 [9, 34, 71, 90, 71, 34]
# 7 [10, 43, 105, 161, 161, 105, 43]
# 8 [11, 53, 148, 266, 322, 266, 148, 53]
# 9 [12, 64, 201, 414, 588, 588, 414, 201, 64]
# 10 [13, 76, 265, 615, 1002, 1176, 1002, 615, 265, 76]
# 11 [14, 89, 341, 880, 1617, 2178, 2178, 1617, 880, 341, 89]
# 12 [15, 103, 430, 1221, 2497, 3795, 4356, 3795, 2497, 1221, 430, 103]
# 13 [16, 118, 533, 1651, 3718, 6292, 8151, 8151, 6292, 3718, 1651, 533, 118]
# 14 [17, 134, 651, 2184, 5369, 10010, 14443, 16302, 14443, 10010, 5369, 2184, 651, 134]
# 15 [18, 151, 785, 2835, 7553, 15379, 24453, 30745, 30745, 24453, 15379, 7553, 2835, 785, 151]
# 16 [19, 169, 936, 3620, 10388, 22932, 39832, 55198, 61490, 55198, 39832, 22932, 10388, 3620, 936, 169]
# 17 [20, 188, 1105, 4556, 14008, 33320, 62764, 95030, 116688, 116688, 95030, 62764, 33320, 14008, 4556, 1105, 188]
# 18 [21, 208, 1293, 5661, 18564, 47328, 96084, 157794, 211718, 233376, 211718, 157794, 96084, 47328, 18564, 5661, 1293, 208]
# ...
